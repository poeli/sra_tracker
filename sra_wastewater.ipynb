# %%
import plotly.express as px
import dash
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_bootstrap_components as dbc
import dash_html_components as html
import dash_table
from dash.dependencies import Input, Output
import pandas as pd

# %%
filename = "data/SraRunTable_wastewater.csv"
df_sra = pd.read_csv(filename)
df_sra['collection_date'] = df_sra['collection_date'].str.split('/').str[0]
df_sra['collection_date'] = pd.to_datetime(df_sra['collection_date'], errors='coerce', utc=True)
df_sra['year'] = pd.DatetimeIndex(df_sra['collection_date']).year

df_sra
# Out:
# /Users/paulli/anaconda3/envs/dash/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (39,41,42,43,44,49,50,51,53,54,58,59,61,62,70,71,75,76,78,79,83,84,85,86,87,88,89,90,91,92,93,94,95,96,98,99,100,101,102,103,104,105,106,107,108,110,111,112,115,117,118,119,122,123,124,125,126,127,128,131,132,133,134,135,136,137,138,139,140,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                Run Assay Type     BioSample  \
# 0       SRR1594353   AMPLICON  SAMN03084139
# 1       SRR1594354   AMPLICON  SAMN03084140
# 2       SRR1594355   AMPLICON  SAMN03084141
# 3       SRR1594356   AMPLICON  SAMN03084142
# 4       SRR1594357   AMPLICON  SAMN03084143
# ...            ...        ...           ...
# 25967  SRR15129104        WGS  SAMN20204354
# 25968  SRR15423510   AMPLICON  SAMN18451212
# 25969  SRR15647125        WGS  SAMN21013704
# 25970  SRR15706745        WGS  SAMN21209615
# 25971  SRR15709844        WGS  SAMN20841589
#
#                                              Center Name Consent   Experiment  \
# 0                      UNIVERSITY OF WISCONSIN-MILWAUKEE  public    SRX718498
# 1                      UNIVERSITY OF WISCONSIN-MILWAUKEE  public    SRX718499
# 2                      UNIVERSITY OF WISCONSIN-MILWAUKEE  public    SRX718500
# 3                      UNIVERSITY OF WISCONSIN-MILWAUKEE  public    SRX718501
# 4                      UNIVERSITY OF WISCONSIN-MILWAUKEE  public    SRX718502
# ...                                                  ...     ...          ...
# 25967                                   BIOBOT ANALYTICS  public  SRX11437828
# 25968  FACULTY OF AGRICULTURE, FOOD & ENVIRONMENT; TH...  public  SRX11725375
# 25969                                   BIOBOT ANALYTICS  public  SRX11944089
# 25970                                   BIOBOT ANALYTICS  public  SRX12002585
# 25971                                   BIOBOT ANALYTICS  public  SRX12005773
#
#                   Instrument LibraryLayout LibrarySelection  \
# 0             Illumina MiSeq        PAIRED              PCR
# 1             Illumina MiSeq        PAIRED              PCR
# 2             Illumina MiSeq        PAIRED              PCR
# 3             Illumina MiSeq        PAIRED              PCR
# 4             Illumina MiSeq        PAIRED              PCR
# ...                      ...           ...              ...
# 25967  Illumina NovaSeq 6000        PAIRED           RT-PCR
# 25968            NextSeq 550        SINGLE              PCR
# 25969  Illumina NovaSeq 6000        PAIRED           RT-PCR
# 25970  Illumina NovaSeq 6000        PAIRED           RT-PCR
# 25971  Illumina NovaSeq 6000        PAIRED           RT-PCR
#
#             LibrarySource  ... wwtp env_package Antibiotic_amendment  \
# 0             METAGENOMIC  ...  NaN         NaN                  NaN
# 1             METAGENOMIC  ...  NaN         NaN                  NaN
# 2             METAGENOMIC  ...  NaN         NaN                  NaN
# 3             METAGENOMIC  ...  NaN         NaN                  NaN
# 4             METAGENOMIC  ...  NaN         NaN                  NaN
# ...                   ...  ...  ...         ...                  ...
# 25967  METATRANSCRIPTOMIC  ...  NaN         NaN                  NaN
# 25968         METAGENOMIC  ...  NaN         NaN                  NaN
# 25969  METATRANSCRIPTOMIC  ...  NaN         NaN                  NaN
# 25970  METATRANSCRIPTOMIC  ...  NaN         NaN                  NaN
# 25971  METATRANSCRIPTOMIC  ...  NaN         NaN                  NaN
#
#       biochem_oxygen_dem incubation_temp Media_type Timepoint ref_biomaterial  \
# 0                    NaN             NaN        NaN       NaN             NaN
# 1                    NaN             NaN        NaN       NaN             NaN
# 2                    306             NaN        NaN       NaN             NaN
# 3                    NaN             NaN        NaN       NaN             NaN
# 4                    NaN             NaN        NaN       NaN             NaN
# ...                  ...             ...        ...       ...             ...
# 25967                NaN             NaN        NaN       NaN             NaN
# 25968                NaN             NaN        NaN       NaN             NaN
# 25969                NaN             NaN        NaN       NaN             NaN
# 25970                NaN             NaN        NaN       NaN             NaN
# 25971                NaN             NaN        NaN       NaN             NaN
#
#        nominal_length (run)    year
# 0                       NaN  2012.0
# 1                       NaN  2012.0
# 2                       NaN  2012.0
# 3                       NaN  2012.0
# 4                       NaN  2012.0
# ...                     ...     ...
# 25967                   NaN  2021.0
# 25968                   NaN  2014.0
# 25969                   NaN  2021.0
# 25970                   NaN  2021.0
# 25971                   NaN  2021.0
#
# [25972 rows x 148 columns]

# %%
# Run,Assay Type,BioSample,Center Name,Consent,Experiment,Instrument,
# LibraryLayout,LibrarySelection,LibrarySource,Organism,Platform,
# ReleaseDate,Sample Name,SRA Study,DATASTORE filetype,DATASTORE provider,DATASTORE region,
# AvgSpotLen,Bases,Bytes,BioProject,Library Name,
# collection_date,geo_loc_name_country,geo_loc_name_country_continent,BioSampleModel,geo_loc_name,
# lat_lon,isolation_source,env_broad_scale,env_local_scale,
# Host,env_medium,ENA-FIRST-PUBLIC (run),ENA-LAST-UPDATE (run),geographic_location_(country_and/or_sea),
# collected_by,sample_name,ww_population,ww_sample_duration,ww_sample_matrix,ww_sample_type,ww_surv_target_1_known_present,ww_surv_target_1,
# INSDC_center_name,INSDC_first_public,INSDC_last_update,INSDC_status,env_biome,env_feature,env_material,INSDC_center_alias,
# geographic_location_(latitude),geographic_location_(longitude),investigation_type,ena_first_public,
# ena_last_update,purpose_of_ww_sampling,sequenced_by,isolate,ww_processing_protocol,ww_sample_site,project_name,Strain,External_Id,
# Submitter_Id,replicate,SRA_accession,Title,ww_surv_jurisdiction,ww_surv_system_sample_id,
# sewage_type,sequencing_method,environment_(biome),environment_(feature),environment_(material),
# wastewater/sludge_environmental_package,Broker_name,samp_size,environmental_sample,
# Is_the_sequenced_pathogen_host_associated?,isolation_source_non_host_associated,
# Alias,ena_checklist,organism (run),collection_date (run),geo_loc_name (run),isolation_source (run),ww_population (run),ww_sample_duration (run),ww_sample_matrix (run),ww_sample_type (run),ww_surv_target_1 (run),samp_mat_process,depth,samp_collect_device,id,name_of_the_sampling_site,rel_to_oxygen,misc_param,description,source_material_ID,wastewater_type,host_subject_id,period_code,pH,site_code,host_sex,Host_Age,host_body_product,replicate_code,Temp,reactor_type,geographic_location_(region_and_locality),Tmp,isol_growth_condt,host_health_state,host_scientific_name,Bioreactor_Code,Sampling_week_designation,sample_type,house,samp_vol_we_dna_ext,samp_store_temp,sample_name_2,sludge_retent_time,location,label,identity,sample_number,elev,samp_store_dur,tot_nitro,BIOME,day,feature,material,wwtp,env_package,Antibiotic_amendment,biochem_oxygen_dem,incubation_temp,Media_type,Timepoint,ref_biomaterial,nominal_length (run)

print(f'number of avil columns: {len(df_sra.columns)}')
# Out:
# number of avil columns: 148

# %%
dimensions_dict = {
    'assay_type': 'Assay Type', 
    'library_source': 'LibrarySource', 
    'platform': 'Platform', 
    'continent': 'geo_loc_name_country_continent',
    'country': 'geo_loc_name_country'
}
dimensions_display = ['Assay Type', 'LibrarySource', 'Platform', 'geo_loc_name_country_continent']

# %%
df_sra[dimensions_display].value_counts()
# Out:
# Assay Type  LibrarySource       Platform     geo_loc_name_country_continent
# AMPLICON    METAGENOMIC         ILLUMINA     Europe                            4056
#                                              Asia                              2971
#                                              North America                     2493
# WGS         METATRANSCRIPTOMIC  ILLUMINA     North America                     2213
# AMPLICON    GENOMIC             ILLUMINA     North America                     2103
#                                                                                ...
# WGS         METAGENOMIC         LS454        North America                        1
# WGA         METAGENOMIC         ILLUMINA     uncalculated                         1
# Hi-C        METAGENOMIC         ILLUMINA     Oceania                              1
# AMPLICON    METAGENOMIC         ION_TORRENT  uncalculated                         1
#                                 CAPILLARY    Asia                                 1
# Length: 146, dtype: int64

# %%
df_sra.describe(include='all')
# Out:
# /var/folders/85/m0d0qjm51wj7gw6dgr_05lvw0009b7/T/ipykernel_61261/3058443914.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_sra.describe(include='all')
#                Run Assay Type     BioSample       Center Name Consent  \
# count        25972      25972         25972             25972   25972
# unique       25972         13         21749               385       1
# top     SRR1594353   AMPLICON  SAMN20326102  BIOBOT ANALYTICS  public
# freq             1      18381          1342              2213   25972
# first          NaN        NaN           NaN               NaN     NaN
# last           NaN        NaN           NaN               NaN     NaN
# mean           NaN        NaN           NaN               NaN     NaN
# std            NaN        NaN           NaN               NaN     NaN
# min            NaN        NaN           NaN               NaN     NaN
# 25%            NaN        NaN           NaN               NaN     NaN
# 50%            NaN        NaN           NaN               NaN     NaN
# 75%            NaN        NaN           NaN               NaN     NaN
# max            NaN        NaN           NaN               NaN     NaN
#
#         Experiment      Instrument LibraryLayout LibrarySelection  \
# count        25972           25972         25972            25972
# unique       25808              35             2               12
# top     SRX3033573  Illumina MiSeq        PAIRED              PCR
# freq            21           14489         21362            17023
# first          NaN             NaN           NaN              NaN
# last           NaN             NaN           NaN              NaN
# mean           NaN             NaN           NaN              NaN
# std            NaN             NaN           NaN              NaN
# min            NaN             NaN           NaN              NaN
# 25%            NaN             NaN           NaN              NaN
# 50%            NaN             NaN           NaN              NaN
# 75%            NaN             NaN           NaN              NaN
# max            NaN             NaN           NaN              NaN
#
#        LibrarySource  ...           wwtp                   env_package  \
# count          25972  ...            249                           244
# unique             6  ...              8                             3
# top      METAGENOMIC  ...  Mallard Creek  MIGS/MIMS/MIMARKS.wastewater
# freq           16538  ...            125                           216
# first            NaN  ...            NaN                           NaN
# last             NaN  ...            NaN                           NaN
# mean             NaN  ...            NaN                           NaN
# std              NaN  ...            NaN                           NaN
# min              NaN  ...            NaN                           NaN
# 25%              NaN  ...            NaN                           NaN
# 50%              NaN  ...            NaN                           NaN
# 75%              NaN  ...            NaN                           NaN
# max              NaN  ...            NaN                           NaN
#
#        Antibiotic_amendment biochem_oxygen_dem incubation_temp Media_type  \
# count                   234                234             234        234
# unique                    5                 94               2          2
# top           no antibiotic     Not applicable              RT         LB
# freq                     61                 81             133        120
# first                   NaN                NaN             NaN        NaN
# last                    NaN                NaN             NaN        NaN
# mean                    NaN                NaN             NaN        NaN
# std                     NaN                NaN             NaN        NaN
# min                     NaN                NaN             NaN        NaN
# 25%                     NaN                NaN             NaN        NaN
# 50%                     NaN                NaN             NaN        NaN
# 75%                     NaN                NaN             NaN        NaN
# max                     NaN                NaN             NaN        NaN
#
#        Timepoint          ref_biomaterial  nominal_length (run)          year
# count      234.0                      190            225.000000  24890.000000
# unique       NaN                       13                   NaN           NaN
# top          NaN  GAC and activate sludge                   NaN           NaN
# freq         NaN                       79                   NaN           NaN
# first        NaN                      NaN                   NaN           NaN
# last         NaN                      NaN                   NaN           NaN
# mean         4.0                      NaN            992.525778   2016.420571
# std          0.0                      NaN           2567.876966      3.349560
# min          4.0                      NaN              0.300000   2001.000000
# 25%          4.0                      NaN            400.000000   2014.000000
# 50%          4.0                      NaN            400.000000   2016.000000
# 75%          4.0                      NaN            400.000000   2019.000000
# max          4.0                      NaN          19999.000000   2064.000000
#
# [13 rows x 148 columns]

# %%
df = df_sra[['Run', 'BioSample', 'BioProject', 'geo_loc_name_country']+dimensions_display]
df = df.fillna('N/A')
ddf = df
df.describe(include='all')
# Out:
#                Run     BioSample   BioProject geo_loc_name_country Assay Type  \
# count        25972         25972        25972                25972      25972
# unique       25972         21749          902                  110         13
# top     SRR1594353  SAMN20326102  PRJNA746354                  USA   AMPLICON
# freq             1          1342         2183                 8465      18381
#
#        LibrarySource  Platform geo_loc_name_country_continent
# count          25972     25972                          25972
# unique             6         7                              8
# top      METAGENOMIC  ILLUMINA                  North America
# freq           16538     24677                           9832

# %%
def fig_parallel_categories(df, dimensions, color_col):
    ddf = df.copy()
    
    # set colors
    c = list(ddf[color_col].unique())
    colors = px.colors.qualitative.Dark24 + px.colors.qualitative.Light24
    c_dict = dict(zip(c, colors[:len(c)]))
    ddf['COLORS'] = ddf[color_col].map(c_dict)
    
    fig = px.parallel_categories(ddf, dimensions=dimensions, color='COLORS')
    fig.update_layout(
        margin=dict(l=20, r=20, t=20, b=20),
        height=600
    )
    return fig

# %%
def get_stats(df):
    sra_num = len(df)
    biosample_num = len(df.BioSample.unique())
    bioproj_num = len(df.BioProject.unique())

    return f'{sra_num} Runs, {biosample_num} BioSamples, {bioproj_num} BioProjects'

# %%
def dropdown_div(dimensions_dict):
    input_list = []

    # add selection option for coloring column
    options = [{'label': key, 'value': val} for key, val in dimensions_dict.items()]
    div = html.Div([
        html.Label('Coloring'),
        dcc.Dropdown(
            id='colored_column',
            value='Assay Type',
            options=options
        ),
    ], style={'width': '12%', 'display': 'inline-block'})

    input_list.append(div)

    # add selection options for dimensions_dict
    for key in dimensions_dict:
        dim = dimensions_dict[key]
        available_idx = df[dim].unique()
        options = [{'label': i, 'value': i} for i in available_idx]
        div = html.Div([
            html.Label(key),
            dcc.Dropdown(
                id=key,
                options=options
            ),
        ], style={'width': '12%', 'display': 'inline-block'})

        input_list.append(div)
        
    return input_list

# %%
app = JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

input_list = dropdown_div(dimensions_dict)

fig = fig_parallel_categories(df, dimensions_display, 'Assay Type')

app.layout = html.Div([
    html.H2(
        children='Wastewater metagenome',
        style={
            'color': '#333333'
        }
    ),
    html.Div(
        id='stats_output',
        children='# Runs, # BioSamples, # BioProjects', 
        style={
            'color': '#777777'
        }
    ),
    html.Div(
        input_list, 
        style={'padding': '15px 5px'}
    ),
    html.Div([
        dcc.Graph(
            id='sra_sankey',
            figure=fig
        )
    ], style={'width': '90%', 'display': 'inline-block', 'padding': '10px 20px'}),
    html.Div([
        dbc.Button("Export SRA", color="primary", id="btn_csv", className="mr-1"),
        dcc.Download(id="download-dataframe-csv")
    ]),
], style={'margin': '10px 20px'})


@app.callback(
    Output('sra_sankey', 'figure'),
    Output('stats_output', 'children'),
    Input('assay_type', 'value'),
    Input('library_source', 'value'),
    Input('platform', 'value'),
    Input('continent', 'value'),
    Input('country', 'value'),
    Input('colored_column', 'value'))
def update_graph(assay_type, library_source, platform, continent, country, colored_column):
    ddf = df
    if assay_type:
        ddf = ddf[ddf[dimensions_dict['assay_type']]==assay_type]
    if library_source:
        ddf = ddf[ddf[dimensions_dict['library_source']]==library_source]
    if platform:
        ddf = ddf[ddf[dimensions_dict['platform']]==platform]
    if continent:
        ddf = ddf[ddf[dimensions_dict['continent']]==continent]
    if country:
        ddf = ddf[ddf[dimensions_dict['country']]==country]
    if not colored_column:
        colored_column = 'Assay Type'
    
    fig = fig_parallel_categories(ddf, dimensions_display, colored_column)

    return fig, get_stats(ddf)


@app.callback(
    Output("download-dataframe-csv", "data"),
    Input("btn_csv", "n_clicks"),
    prevent_initial_call=True,
)
def func(n_clicks):
    return dcc.send_data_frame(df_sra[df_sra.Run.isin(ddf.Run)].to_csv, "sra_wastewater.csv")


# Run app and display result inline in the notebook
app.run_server(mode='jupyterlab', debug=True)
# Out:
# /Users/paulli/anaconda3/envs/dash/lib/python3.9/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
